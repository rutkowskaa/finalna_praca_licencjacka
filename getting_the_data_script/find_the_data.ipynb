# %%
import Get_Data
import features
import pandas as pd
import numpy as np
# Out:
# Unable to determine R home: [WinError 2] Nie można odnaleźć określonego pliku
# Unable to determine R library path: Command '('C:\\Program Files\\R\\R-4.1.2\\bin\\Rscript', '-e', 'cat(Sys.getenv("LD_LIBRARY_PATH"))')' returned non-zero exit status 1.

# %%
data = Get_Data.Get_Data("^IXIC", start="2018-08-22", end="2019-10-30", interval="1d").make_diff()
data
# Out:
# make_diff()
# Date
# 2018-08-22    29.930176
# 2018-08-23   -10.640137
# 2018-08-24    67.520020
# 2018-08-27    71.919922
# 2018-08-28    12.140137
#                 ...
# 2019-10-23    15.490234
# 2019-10-24    66.009766
# 2019-10-25    57.320312
# 2019-10-28    82.870117
# 2019-10-29   -49.140625
# Name: Close, Length: 299, dtype: float64

# %%
Get_Data.Get_Data.analiza_statystyczna_szeregu(data)
# Out:
# analiza_statystyczna_szeregu
# ---------------------------------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------------------------------------------
# --                                                            SPRAWDZENIE STACJONARNOŚCI                                                         --
# --                                                                  DANE PODSTAWOWE                                                                --
# ---------------------------------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------------------------------------------------------
# ...
